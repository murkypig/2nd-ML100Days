# %% [markdown]
# # 練習時間
# ## 作業1:
#
# ### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# #### <font color=#D2691E >   → [Using News to Predict Stock Movements] (https://www.kaggle.com/c/two-sigma-financial-news/data)</font>
#
# #### 1.你選的這組資料為何重要
# #### <font color=#D2691E >   → 對於股市的股價可說是瞬息萬變，所以對於投資者來說，市場數據分析是非常至關重要的工具，這組資料重要的地方在於，我們將如何利用新聞數據去預測未來的股價</font>
# #### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# #### <font color=#D2691E >   → 由Intrinio提供的市場數據（2007年至今）包含金融市場信息，如開盤價，收盤價，交易量，計算回報等。新聞數據（2007年至今）資料來源：湯森路透 - 包含有關資產的新聞文章/警報信息，如文章詳情，情緒和其他評論。</font>
# #### 3. 蒐集而來的資料型態為何
# #### <font color=#D2691E >   → 結構化。</font>
# #### 4. 這組資料想解決的問題如何評估
# #### <font color=#D2691E >   → 當這組資料預期未來會獲利則提供最高1.0的分數，預期虧損則提供最低 -1.0的分數，不知道則設為 0.0。</font>
#
#
# ## 作業2:
#
# ### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# #### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# #### <font color=#D2691E >   → 搭一次就不搭的乘客的原因，也就是客群流失率，也就是發現這個原因去改善應該可以提升業績。</font>
# #### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# #### <font color=#D2691E >   → 顧客離開的原因，透過問卷的方式收集。</font>
# ### 3. 蒐集而來的資料型態為何
# #### <font color=#D2691E >   → 非結構化</font>
# #### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# #### <font color=#D2691E >   → 當解決第一步滿意的問題後，帶入模型是否可以預期提升業績。</font>

# %% [markdown]
# ## 作業3：
#
# ### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    """
    請完成這個 Function 後往下執行
    """
    mse = np.mean((y - y_hat)**2)
    return mse

# %%
def mean_absolute_error(y, y_hat):
    
    mae = np.mean(abs(y - y_hat))
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 289.999
# The Mean absolute error is 13.380
